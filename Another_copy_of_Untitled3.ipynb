# %% [markdown]
# <a href="https://colab.research.google.com/github/prakash-6-in/Calicstud/blob/main/Another_copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gitgitgitgit clone https://github.com/calesthio/OpenMontage.github
# Out:
# Cloning into 'OpenMontage.github'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !codex login
# Out:
# /bin/bash: line 1: codex: command not found

# %%
# !npm install -g @openai/codex
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# added 2 packages in 8s
# ⠇npm notice
# npm notice New major version of npm available! 10.8.2 -> 12.0.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.2
# npm notice To update run: npm install -g npm@12.0.2
# npm notice
# ⠇

# %%
# !codex --version
# Out:
# codex-cli 0.154.0

# %%
# !codex login
# Out:
# Starting local login server on http://localhost:1455.
# If your browser did not open, navigate to this URL to authenticate:
#
# https://auth.openai.com/oauth/authorize?response_type=code&client_id=app_EMoamEEZ73f0CkXaXp7hrann&redirect_uri=http%3A%2F%2Flocalhost%3A1455%2Fauth%2Fcallback&scope=openid%20profile%20email%20offline_access%20api.connectors.read%20api.connectors.invoke&code_challenge=-y6K1pz7b51XlM_X-frxoKmTUQtxuBjsuFxRtD-xxHg&code_challenge_method=S256&id_token_add_organizations=true&codex_cli_simplified_flow=true&state=mHCf5Dqu-E4VphJDemucbVIrqqJTi3P7SDVtLNZa3Ng&originator=codex_cli_rs
#
# On a remote or headless machine? Use `codex login --device-auth` instead.

# %%
# !codex login --device-auth
# Out:
# Welcome to Codex [v0.154.0]
# OpenAI's command-line coding agent
#
# Follow these steps to sign in with ChatGPT using device code authorization:
#
# 1. Open this link in your browser and sign in to your account
#    https://auth.openai.com/codex/device
#
# 2. Enter this one-time code (expires in 15 minutes)
#    B5VW-G2AET
#
# Continue only if you started this login in Codex. If a website or another person gave you this code, cancel.

# %%
# !cd /content/OpenMontage-main && ls -d .claude .codex .cursor 2>/dev/null
# Out:
# /bin/bash: line 1: cd: /content/OpenMontage-main: No such file or directory

# %%
# !ls -la /content
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Sep  4 13:25 .
# drwxr-xr-x 1 root root 4096 Sep 13 14:08 ..
# drwxr-xr-x 4 root root 4096 Sep  4 13:25 .config
# drwxr-xr-x 1 root root 4096 Sep  4 13:25 sample_data

# %%
# !wget -q -O /content/OpenMontage.zip https://github.com/calesthio/OpenMontage/archive/refs/heads/main.zip && rm -rf /content/OpenMontage-main && unzip -q -o /content/OpenMontage.zip -d /content

# %%
# %cd /content/OpenMontage-main
# !make setup
# Out:
# /content/OpenMontage-main
# ==> Creating virtual environment with uv (Python 3.10+): .venv
# ...
# Using CPython 3.10.21
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# ==> Installing Python dependencies...
# .venv/bin/python -m pip install -r requirements.txt
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.6/472.6 kB 47.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 72.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 66.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 35.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.2 MB/s eta 0:00:00
# ...

# %%
# !which codex || true; which cclaudelaude || true; which cursor || true; which copilot || true

# %%
# !git --version--version--version--version
# Out:
# git version 2.43.0

# %%
# !npm install -g @openai/codexcodex
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋
# added 2 packages in 8s
# ⠋

# %%
# !codex --version
# Out:
# codex-cli 0.154.0

# %%
# !codex login
# Out:
# Starting local login server on http://localhost:1455.
# If your browser did not open, navigate to this URL to authenticate:
#
# https://auth.openai.com/oauth/authorize?response_type=code&client_id=app_EMoamEEZ73f0CkXaXp7hrann&redirect_uri=http%3A%2F%2Flocalhost%3A1455%2Fauth%2Fcallback&scope=openid%20profile%20email%20offline_access%20api.connectors.read%20api.connectors.invoke&code_challenge=0-nqDsR3JBb5RHj69c8Ct6q6tZG0WQ8euOY6pRQvLlU&code_challenge_method=S256&id_token_add_organizations=true&codex_cli_simplified_flow=true&state=zMisoyxUh976eJEFmvpQytyAOw1BKB5_HHKDkY_m33k&originator=codex_cli_rs
#
# On a remote or headless machine? Use `codex login --device-auth` instead.

# %%
# !git ls-remote https://github.com/calesthio/OpenMontage.git HEAD
# Out:
# 08e2151fa02de28a5d6a312b3d575692bf147ad7	HEAD

# %%
# !git clone https://github.com/calesthio/OpenMontage.github
# Out:
# Cloning into 'OpenMontage.github'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !wget -O OpenMontage.zip https://github.com/calesthio/OpenMontage/archive/refs/heads/main.zip
# Out:
# --2026-09-13 05:28:43--  https://github.com/calesthio/OpenMontage/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/calesthio/OpenMontage/zip/refs/heads/main [following]
# --2026-09-13 05:28:43--  https://codeload.github.com/calesthio/OpenMontage/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘OpenMontage.zip’
#
# OpenMontage.zip         [                <=> ]  73.67M  19.9MB/s    in 4.0s
#
# 2026-09-13 05:28:47 (18.2 MB/s) - ‘OpenMontage.zip’ saved [77252181]

# %%
# !unzip -q OpenMontage.zip
# Out:
# replace OpenMontage-main/.agents/skills/3d-asset-generation/SKILL.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/3d-asset-generation/agents/openai.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/acestep/SKILL.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/agents/SKILL.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/agents/references/agent-configuration.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/agents/references/client-tools.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/agents/references/installation.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# replace OpenMontage-main/.agents/skills/agents/references/outbound-calls.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
# ...

# %%
# !rm -rf OpenMontage-main
# !unzip -q -o OpenMontage.zip

# %%
# !ls -la
# Out:
# total 75464
# drwxr-xr-x  1 root root     4096 Sep 13 05:35 .
# drwxr-xr-x  1 root root     4096 Sep 13 04:43 ..
# drwxr-xr-x  4 root root     4096 Sep  4 13:25 .config
# drwxr-xr-x 20 root root     4096 Sep  6 05:02 OpenMontage-main
# -rw-r--r--  1 root root 77252181 Sep 13 05:28 OpenMontage.zip
# drwxr-xr-x  1 root root     4096 Sep  4 13:25 sample_data

# %%
# !ls -d OpenMontage-main
# Out:
# OpenMontage-main

# %%
# !ls -d OpenMontage-main
# Out:
# OpenMontage-main

# %%
# !sed -n '1,220p' OpenMontage-main/README.md
# Out:
# <p align="center">
#   <picture>
#     <source media="(prefers-color-scheme: dark)" srcset="assets/monty-dark.svg">
#     <img src="assets/monty-light.svg" alt="Monty the Clapper — the official mascot of OpenMontage" width="200">
#   </picture>
# </p>
#
# <p align="center"><sub><em>Monty the Clapper — the official mascot of OpenMontage</em></sub></p>
#
# <h1 align="center">OpenMontage</h1>
#
# <p align="center"><strong>The first open-source, agentic video production system.</strong></p>
#
# <p align="center">
#   <a href="https://openmontage.video"><img src="https://img.shields.io/badge/Website-openmontage.video-d14a28?style=for-the-badge" alt="openmontage.video"></a>
# </p>
#
# <p align="center">
#   <a href="#start-from-a-video-you-already-love">Paste A Video</a> &nbsp;·&nbsp;
#   <a href="#quick-start">Quick Start</a> &nbsp;·&nbsp;
#   <a href="#try-these-prompts">Try These Prompts</a> &nbsp;·&nbsp;
#   <a href="#pipelines">Pipelines</a> &nbsp;·&nbsp;
# ...

# %%
# !python --version
# Out:
# Python 3.13.15

# %%
# !cd OpenMontage-main && ls
# Out:
# AGENT_GUIDE.md	 CURSOR.md	     PROMPT_GALLERY.md	   schemas
# AGENTS.md	 diagram.png	     README.md		   scripts
# assets		 docs		     README_zh-CN.md	   setup.py
# backlot		 ink-theater	     remotion-composer	   skills
# CLAUDE.md	 lib		     render_demo.py	   styles
# CODEX.md	 LICENSE	     render-demo.sh	   tests
# config.yaml	 Makefile	     requirements-dev.txt  tools
# CONTRIBUTING.md  pipeline_defs	     requirements-gpu.txt
# COPILOT.md	 PROJECT_CONTEXT.md  requirements.txt

# %%
# !cd OpenMontage-main && ls -la
# Out:
# total 372
# drwxr-xr-x 20 root root  4096 Sep  6 05:02 .
# drwxr-xr-x  1 root root  4096 Sep 13 05:35 ..
# -rw-r--r--  1 root root 48043 Sep  6 05:02 AGENT_GUIDE.md
# drwxr-xr-x  3 root root  4096 Sep  6 05:02 .agents
# -rw-r--r--  1 root root   384 Sep  6 05:02 AGENTS.md
# drwxr-xr-x  3 root root  4096 Sep  6 05:02 assets
# drwxr-xr-x  3 root root  4096 Sep  6 05:02 backlot
# drwxr-xr-x  4 root root  4096 Sep  6 05:02 .claude
# -rw-r--r--  1 root root   402 Sep  6 05:02 CLAUDE.md
# drwxr-xr-x  3 root root  4096 Sep  6 05:02 .codex
# -rw-r--r--  1 root root   268 Sep  6 05:02 CODEX.md
# -rw-r--r--  1 root root   896 Sep  6 05:02 config.yaml
# -rw-r--r--  1 root root   523 Sep  6 05:02 CONTRIBUTING.md
# -rw-r--r--  1 root root   270 Sep  6 05:02 COPILOT.md
# drwxr-xr-x  4 root root  4096 Sep  6 05:02 .cursor
# -rw-r--r--  1 root root   269 Sep  6 05:02 CURSOR.md
# -rw-r--r--  1 root root  5336 Sep  6 05:02 diagram.png
# drwxr-xr-x  4 root root  4096 Sep  6 05:02 docs
# ...

# %%
# !cd OpenMontage-main && python -m pip install -r requirements.txt

# %%
# !cd OpenMontage-main && make setupsetup
# Out:
# /bin/bash: line 1: cd: OpenMontage-main: No such file or directory

# %%
# !pwd && ls -la
# Out:
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Sep  4 13:25 .
# drwxr-xr-x 1 root root 4096 Sep 13 13:24 ..
# drwxr-xr-x 4 root root 4096 Sep  4 13:25 .config
# drwxr-xr-x 1 root root 4096 Sep  4 13:25 sample_data

# %%
# !cd OpenMontage-main && ffmpeg -version | head -1 && node --version
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
# v20.19.0

# %%
# !cd OpenMontage-main && make setup
# Out:
# ==> Creating virtual environment with uv (Python 3.10+): .venv
# ...
# Using CPython 3.10.21
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# ==> Installing Python dependencies...
# .venv/bin/python -m pip install -r requirements.txt
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.6/472.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 29.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.0 MB/s eta 0:00:00
# ...

# %%
# !cd OpenMontage-main && python -c "from tools.tool_registry import registry; import json; registry.discover(); print(json.dumps(registry.support_envelope(), indent=2))"
# Out:
# {
#   "audio_energy": {
#     "name": "audio_energy",
#     "version": "0.1.0",
#     "tier": "core",
#     "capability": "analysis",
#     "provider": "ffmpeg",
#     "stability": "production",
#     "status": "available",
#     "execution_mode": "sync",
#     "determinism": "deterministic",
#     "runtime": "local",
#     "module_path": "tools.analysis.audio_energy",
#     "usage_location": "/content/OpenMontage-main/tools/analysis/audio_energy.py",
#     "dependencies": [
#       "binary:ffmpeg"
#     ],
#     "install_instructions": "Install ffmpeg:\n  Windows: winget install ffmpeg\n  macOS: brew install ffmpeg\n  Linux: sudo apt install ffmpeg",
#     "capabilities": [
#       "find_music_offset",
#       "energy_profile",
#       "best_window",
#       "loop_recommendation"
#     ],
#     "input_schema": {
#       "type": "object",
#       "required": [
#         "input_path"
#       ],
#       "properties": {
#         "input_path": {
#           "type": "string",
# ...

# %%
# !cd OpenMontage-main && python -c "from tools.tool_registry import registry; registry.discover(); print(registry.support_envelope())" 2>&1 | tail -30
# Out:
# {'audio_energy': {'name': 'audio_energy', 'version': '0.1.0', 'tier': 'core', 'capability': 'analysis', 'provider': 'ffmpeg', 'stability': 'production', 'status': 'available', 'execution_mode': 'sync', 'determinism': 'deterministic', 'runtime': 'local', 'module_path': 'tools.analysis.audio_energy', 'usage_location': '/content/OpenMontage-main/tools/analysis/audio_energy.py', 'dependencies': ['binary:ffmpeg'], 'install_instructions': 'Install ffmpeg:\n  Windows: winget install ffmpeg\n  macOS: brew install ffmpeg\n  Linux: sudo apt install ffmpeg', 'capabilities': ['find_music_offset', 'energy_profile', 'best_window', 'loop_recommendation'], 'input_schema': {'type': 'object', 'required': ['input_path'], 'properties': {'input_path': {'type': 'string', 'description': 'Path to audio file (mp3, wav, ogg, etc.)'}, 'video_duration_seconds': {'type': 'number', 'description': 'Duration of the video this music will accompany. Used to recommend looping and find the best offset window.'}, 'energ
# ...

# %%
# !cdcd OpenMontage-mainOpenMontage-main && make demo
# Out:
# /bin/bash: line 1: cd: OpenMontage-mainOpenMontage-main: No such file or directory

# %%
# !find OpenMontage-main -type f \( -name "*.mp4" -o -name "*.mov" -o -name "*.webm" \) -printf "%p\n"
# Out:
# OpenMontage-main/.agents/skills/hyperframes-animation/examples/assets/hyperframes-showcase-hypecard.mp4
# OpenMontage-main/.agents/skills/hyperframes-animation/examples/assets/background-tech-data-flow.mp4
# OpenMontage-main/assets/signal-from-tomorrow-demo.mp4

# %%
# %cd /content/OpenMontage-main
# !make demo
# Out:
# /content/OpenMontage-main
# ==> Using existing virtual environment: .venv
# ==> Rendering zero-key demo videos (no API keys needed)...
#     These use only Remotion components — animated charts, text, data viz.
#
# .venv/bin/python render_demo.py
#
# Rendering: code-to-screen
# Props:     /content/OpenMontage-main/remotion-composer/public/demo-props/code-to-screen.json
# Output:    /content/OpenMontage-main/projects/demos/renders/code-to-screen.mp4
#
# ⠙Downloading Chrome Headless Shell https://www.remotion.dev/chrome-headless-shell
# ...

# %%
# !find /content/OpenMontage-main -type f -name "*.mp4"
# Out:
# /content/OpenMontage-main/.agents/skills/hyperframes-animation/examples/assets/hyperframes-showcase-hypecard.mp4
# /content/OpenMontage-main/.agents/skills/hyperframes-animation/examples/assets/background-tech-data-flow.mp4
# /content/OpenMontage-main/projects/demos/renders/code-to-screen.mp4
# /content/OpenMontage-main/projects/demos/renders/world-in-numbers.mp4
# /content/OpenMontage-main/projects/demos/renders/focusflow-pitch.mp4
# /content/OpenMontage-main/assets/signal-from-tomorrow-demo.mp4

# %%
Create a 20-second cinematic dark-horror vivideodeo of a terrifying humanoid demon slowly walking toward the camera through a foggy abandoned forest at night.

The demon should have an unnatural tall silhouette, subtle glowing eyes, long distorted limbs, and realistic movement. Use slow tracking camera movement, dense atmospheric fog, moonlight filtering through dead trees, subtle handheld motion, and deep shadows.

Start with a distant silhouette, gradually reveal the creature as it approaches, then end with a sudden close-up of its face.

Style: photorealistic cinematic horror, dark atmospheric lighting, realistic textures, suspenseful pacing.
Aspect ratio: 9:16 vertical, optimized for YouTube Shorts.
No text, no subtitles, no watermark, no gore.
# Out:
#   File "/tmp/ipykernel_1145/2426037777.py", line 1
#     Create a 20-second cinematic dark-horror vivideodeo of a terrifying humanoid demon slowly walking toward the camera through a foggy abandoned forest at night.
#            ^
# SyntaxError: invalid syntax

# %%
# !wget -q -O OpenMontage.zip https://github.com/calesthio/OpenMontage/archive/refs/heads/main.zip && unzip -q -o OpenMontage.zip
